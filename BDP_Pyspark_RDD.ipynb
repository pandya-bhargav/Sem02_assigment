# %% [markdown]
# # Pyspark Install

# %%
# !pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyspark in /usr/local/lib/python3.9/dist-packages (3.3.2)
# Requirement already satisfied: py4j==0.10.9.5 in /usr/local/lib/python3.9/dist-packages (from pyspark) (0.10.9.5)

# %% [markdown]
# # Task 1

# %%
import numpy as np
from pyspark import SparkContext

# Initialize SparkContext
spark_context = SparkContext.getOrCreate()
np.random.seed(3)
n = np.random.randint(0, 11, 100)

# Create RDD using parallelize function
rdd = spark_context.parallelize(n)
function = rdd.countByValue()

for n, count in function.items():
    print(f"{n} come into view {count} times.")
# Out:
# 10 come into view 10 times.
# 8 come into view 13 times.
# 9 come into view 5 times.
# 3 come into view 4 times.
# 0 come into view 15 times.
# 5 come into view 11 times.
# 7 come into view 10 times.
# 6 come into view 4 times.
# 4 come into view 8 times.
# 1 come into view 13 times.
# 2 come into view 7 times.

# %% [markdown]
# # Task 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from pyspark import SparkContext
import re

# Initialize SparkContext
spark_context = SparkContext.getOrCreate()
text = spark_context.textFile('/content/drive/MyDrive/Assigmnet/text8/text8')

# Split each line into words 
words_rdd = text.flatMap(lambda line: re.findall(r'\w+', line.lower()))
freq = words_rdd.countByValue()

# Filter words containing the letter 'a'. We can choose any letter instead of a
words_freq = words_rdd.filter(lambda word: 'a' in word).countByValue()

for w, c in freq.items(): # where w for word and c for count
    print(f"'{w}' appears {c} times.")
    
for w, c in words_freq.items():
    print(f"'{w}' letter 'a' appears {c} times.")
# Out:
# Streaming output truncated to the last 5000 lines.
# 'arml' letter 'a' appears 1 times.
# 'amatyc' letter 'a' appears 1 times.
# 'orowan' letter 'a' appears 1 times.
# 'erraticimpact' letter 'a' appears 1 times.
# 'polanyiana' letter 'a' appears 1 times.
# 'denaturant' letter 'a' appears 2 times.
# 'autothermal' letter 'a' appears 1 times.
# 'bioalcohol' letter 'a' appears 2 times.
# 'denitrification' letter 'a' appears 2 times.
# 'butterfat' letter 'a' appears 5 times.
# 'indigestability' letter 'a' appears 1 times.
# 'pantothenic' letter 'a' appears 1 times.
# 'counterclaim' letter 'a' appears 1 times.
# 'kradjian' letter 'a' appears 1 times.
# 'ladled' letter 'a' appears 1 times.
# 'resealable' letter 'a' appears 1 times.
# 'paks' letter 'a' appears 1 times.
# 'unrefrigerated' letter 'a' appears 2 times.
# 'somatotropin' letter 'a' appears 1 times.
# 'pagaent' letter 'a' appears 1 times.
# 'strippergates' letter 'a' appears 1 times.
# 'biomagnetism' letter 'a' appears 1 times.
# 'magnetoreceptor' letter 'a' appears 3 times.
# 'magnetoanalyzer' letter 'a' appears 1 times.
# 'metamagnetism' letter 'a' appears 1 times.
# 'superparamagnetism' letter 'a' appears 1 times.
# 'magnetars' letter 'a' appears 1 times.
# 'nonmagnetized' letter 'a' appears 1 times.
# 'monolayers' letter 'a' appears 1 times.
# 'micromagnetism' letter 'a' appears 1 times.
# 'wondermagnet' letter 'a' appears 1 times.
# 'magfaq' letter 'a' appears 1 times.
# 'scientiapress' letter 'a' appears 1 times.
# 'infima' letter 'a' appears 1 times.
# 'ultrafilters' letter 'a' appears 1 times.
# 'rasiowa' letter 'a' appears 1 times.
# 'ultraproducts' letter 'a' appears 1 times.
# 'ultrafiltres' letter 'a' appears 1 times.
# 'brazing' letter 'a' appears 1 times.
# 'metallurgists' letter 'a' appears 2 times.
# 'assachusetts' letter 'a' appears 2 times.
# 'rogramming' letter 'a' appears 2 times.
# 'pappalardo' letter 'a' appears 3 times.
# 'datatree' letter 'a' appears 2 times.
# 'ifcap' letter 'a' appears 1 times.
# 'hardhats' letter 'a' appears 1 times.
# 'globals' letter 'a' appears 4 times.
# 'datastore' letter 'a' appears 3 times.
# 'sqtable' letter 'a' appears 1 times.
# 'stringvar' letter 'a' appears 2 times.
# 'argumentless' letter 'a' appears 1 times.
# 'postrelational' letter 'a' appears 1 times.
# 'formatter' letter 'a' appears 1 times.
# 'riebau' letter 'a' appears 1 times.
# 'farday' letter 'a' appears 1 times.
# 'zantedeschi' letter 'a' appears 2 times.
# 'magnetising' letter 'a' appears 1 times.
# 'fullerian' letter 'a' appears 1 times.
# 'sandemanian' letter 'a' appears 2 times.
# 'affinal' letter 'a' appears 2 times.
# 'nonmonogamy' letter 'a' appears 1 times.
# 'nambudiri' letter 'a' appears 1 times.
# 'henogamy' letter 'a' appears 1 times.
# 'gothra' letter 'a' appears 2 times.
# 'shishyas' letter 'a' appears 2 times.
# 'abhimanyu' letter 'a' appears 1 times.
# 'uttra' letter 'a' appears 1 times.
# 'bohannan' letter 'a' appears 1 times.
# 'mahr' letter 'a' appears 1 times.
# 'necessaties' letter 'a' appears 1 times.
# 'arrearage' letter 'a' appears 1 times.
# 'misyar' letter 'a' appears 1 times.
# 'sororate' letter 'a' appears 1 times.
# 'applebride' letter 'a' appears 1 times.
# 'midjungards' letter 'a' appears 1 times.
# 'mittilagart' letter 'a' appears 3 times.
# 'medja' letter 'a' appears 1 times.
# 'meddila' letter 'a' appears 1 times.
# 'medjan' letter 'a' appears 1 times.
# 'gharto' letter 'a' appears 1 times.
# 'jormungand' letter 'a' appears 2 times.
# 'geard' letter 'a' appears 1 times.
# 'arendel' letter 'a' appears 1 times.
# 'varsuuilhit' letter 'a' appears 1 times.
# 'uallit' letter 'a' appears 1 times.
# 'midgar' letter 'a' appears 1 times.
# 'nephandi' letter 'a' appears 4 times.
# 'wayfaring' letter 'a' appears 1 times.
# 'solificati' letter 'a' appears 1 times.
# 'steadings' letter 'a' appears 1 times.
# 'dreamspeakers' letter 'a' appears 1 times.
# 'euthanatos' letter 'a' appears 1 times.
# 'roleplayers' letter 'a' appears 1 times.
# 'ander' letter 'a' appears 1 times.
# 'grazier' letter 'a' appears 2 times.
# 'wannon' letter 'a' appears 2 times.
# 'tamie' letter 'a' appears 2 times.
# 'macqaurie' letter 'a' appears 1 times.
# 'baulderstone' letter 'a' appears 1 times.
# 'mupra' letter 'a' appears 1 times.
# 'chatswood' letter 'a' appears 1 times.
# 'stuvac' letter 'a' appears 1 times.
# 'anansie' letter 'a' appears 1 times.
# 'flameland' letter 'a' appears 1 times.
# 'nonlinearities' letter 'a' appears 1 times.
# 'alembertian' letter 'a' appears 2 times.
# 'codifferential' letter 'a' appears 1 times.
# 'aharonov' letter 'a' appears 1 times.
# 'proca' letter 'a' appears 1 times.
# 'neerlandaies' letter 'a' appears 1 times.
# 'dynamique' letter 'a' appears 1 times.
# 'macrossan' letter 'a' appears 1 times.
# 'metrization' letter 'a' appears 5 times.
# 'uniformizability' letter 'a' appears 1 times.
# 'rhau' letter 'a' appears 1 times.
# 'schlottau' letter 'a' appears 1 times.
# 'headstreams' letter 'a' appears 2 times.
# 'burgkunstadt' letter 'a' appears 1 times.
# 'staffelstein' letter 'a' appears 1 times.
# 'volkach' letter 'a' appears 1 times.
# 'marktheidenfeld' letter 'a' appears 1 times.
# 'perusia' letter 'a' appears 2 times.
# 'naucholus' letter 'a' appears 1 times.
# 'signalized' letter 'a' appears 1 times.
# 'polla' letter 'a' appears 1 times.
# 'congregazione' letter 'a' appears 1 times.
# 'mariotto' letter 'a' appears 4 times.
# 'albertinelli' letter 'a' appears 3 times.
# 'wracking' letter 'a' appears 2 times.
# 'faultfinding' letter 'a' appears 1 times.
# 'spareribs' letter 'a' appears 1 times.
# 'laobing' letter 'a' appears 1 times.
# 'aeeneh' letter 'a' appears 1 times.
# 'arzhang' letter 'a' appears 1 times.
# 'nadim' letter 'a' appears 1 times.
# 'scythianus' letter 'a' appears 2 times.
# 'buddas' letter 'a' appears 1 times.
# 'isaia' letter 'a' appears 1 times.
# 'manicheism' letter 'a' appears 1 times.
# 'papyrologie' letter 'a' appears 1 times.
# 'epigraphik' letter 'a' appears 1 times.
# 'manichaeanism' letter 'a' appears 2 times.
# 'quadripartite' letter 'a' appears 1 times.
# 'psattiq' letter 'a' appears 1 times.
# 'perisan' letter 'a' appears 1 times.
# 'manichaens' letter 'a' appears 1 times.
# 'dualists' letter 'a' appears 1 times.
# 'manichaeaism' letter 'a' appears 1 times.
# 'manichaicus' letter 'a' appears 1 times.
# 'allberry' letter 'a' appears 1 times.
# 'zsuszanna' letter 'a' appears 1 times.
# 'manichaen' letter 'a' appears 1 times.
# 'indan' letter 'a' appears 1 times.
# 'renova' letter 'a' appears 1 times.
# 'abook' letter 'a' appears 1 times.
# 'kamoun' letter 'a' appears 1 times.
# 'karkoum' letter 'a' appears 1 times.
# 'bsar' letter 'a' appears 1 times.
# 'kasbour' letter 'a' appears 1 times.
# 'zaafrane' letter 'a' appears 1 times.
# 'tagine' letter 'a' appears 1 times.
# 'reasty' letter 'a' appears 1 times.
# 'pastilla' letter 'a' appears 1 times.
# 'tajine' letter 'a' appears 1 times.
# 'tangia' letter 'a' appears 1 times.
# 'harira' letter 'a' appears 1 times.
# 'ghzal' letter 'a' appears 1 times.
# 'shebakia' letter 'a' appears 1 times.
# 'sharbats' letter 'a' appears 1 times.
# 'fastfood' letter 'a' appears 3 times.
# 'djemaa' letter 'a' appears 4 times.
# 'fna' letter 'a' appears 5 times.
# 'bocadillo' letter 'a' appears 2 times.
# 'mahlaba' letter 'a' appears 1 times.
# 'mahlabas' letter 'a' appears 1 times.
# 'bocadillos' letter 'a' appears 1 times.
# 'tajines' letter 'a' appears 1 times.
# 'kasbah' letter 'a' appears 1 times.
# 'fatema' letter 'a' appears 1 times.
# 'clintonians' letter 'a' appears 1 times.
# 'spoilsman' letter 'a' appears 1 times.
# 'fendall' letter 'a' appears 1 times.
# 'lumberjacks' letter 'a' appears 1 times.
# 'aroostock' letter 'a' appears 1 times.
# 'lindenwald' letter 'a' appears 3 times.
# 'barnburner' letter 'a' appears 1 times.
# 'barnburners' letter 'a' appears 1 times.
# 'clothmaking' letter 'a' appears 1 times.
# 'nailbiting' letter 'a' appears 1 times.
# 'baggygreen' letter 'a' appears 1 times.
# 'reindustrialize' letter 'a' appears 1 times.
# 'reindustrialization' letter 'a' appears 1 times.
# 'nonparticipation' letter 'a' appears 2 times.
# 'milward' letter 'a' appears 3 times.
# 'hardach' letter 'a' appears 1 times.
# 'fossedal' letter 'a' appears 1 times.
# 'perrenial' letter 'a' appears 1 times.
# 'arkes' letter 'a' appears 1 times.
# 'schain' letter 'a' appears 1 times.
# 'narozhna' letter 'a' appears 1 times.
# 'alginin' letter 'a' appears 1 times.
# 'internalists' letter 'a' appears 3 times.
# 'darwinizing' letter 'a' appears 1 times.
# 'foreward' letter 'a' appears 2 times.
# 'microinteractions' letter 'a' appears 1 times.
# 'phonautograph' letter 'a' appears 1 times.
# 'claywater' letter 'a' appears 1 times.
# 'shirtwaist' letter 'a' appears 1 times.
# 'rapin' letter 'a' appears 1 times.
# 'bedelia' letter 'a' appears 1 times.
# 'cammi' letter 'a' appears 1 times.
# 'granato' letter 'a' appears 1 times.
# 'wladimir' letter 'a' appears 1 times.
# 'nobunari' letter 'a' appears 1 times.
# 'chikamasa' letter 'a' appears 1 times.
# 'jailyn' letter 'a' appears 1 times.
# 'potagannissing' letter 'a' appears 1 times.
# 'galets' letter 'a' appears 1 times.
# 'skillagalee' letter 'a' appears 1 times.
# 'katechay' letter 'a' appears 1 times.
# 'cheneaux' letter 'a' appears 2 times.
# 'oscoda' letter 'a' appears 1 times.
# 'nauibinaway' letter 'a' appears 1 times.
# 'waugoshance' letter 'a' appears 1 times.
# 'amyraldus' letter 'a' appears 1 times.
# 'amyraldianism' letter 'a' appears 1 times.
# 'daill' letter 'a' appears 1 times.
# 'sacerdotio' letter 'a' appears 1 times.
# 'cappel' letter 'a' appears 1 times.
# 'salmurienses' letter 'a' appears 1 times.
# 'universalismus' letter 'a' appears 1 times.
# 'abaissement' letter 'a' appears 1 times.
# 'creance' letter 'a' appears 1 times.
# 'estat' letter 'a' appears 1 times.
# 'apres' letter 'a' appears 1 times.
# 'oraison' letter 'a' appears 1 times.
# 'dominicale' letter 'a' appears 1 times.
# 'saigey' letter 'a' appears 1 times.
# 'jahrbb' letter 'a' appears 1 times.
# 'gallicanae' letter 'a' appears 1 times.
# 'goolwa' letter 'a' appears 3 times.
# 'kobathatang' letter 'a' appears 1 times.
# 'peindjalang' letter 'a' appears 1 times.
# 'tailem' letter 'a' appears 3 times.
# 'waku' letter 'a' appears 1 times.
# 'muldjewangk' letter 'a' appears 1 times.
# 'lalangengall' letter 'a' appears 1 times.
# 'wotojobaluk' letter 'a' appears 1 times.
# 'blandowski' letter 'a' appears 1 times.
# 'paddlewheeler' letter 'a' appears 1 times.
# 'moama' letter 'a' appears 2 times.
# 'echuca' letter 'a' appears 8 times.
# 'tocumwal' letter 'a' appears 1 times.
# 'wahgunyah' letter 'a' appears 1 times.
# 'riverina' letter 'a' appears 1 times.
# 'blanchetown' letter 'a' appears 1 times.
# 'torrumbarry' letter 'a' appears 2 times.
# 'wodonga' letter 'a' appears 2 times.
# 'mulwala' letter 'a' appears 1 times.
# 'yarrawonga' letter 'a' appears 1 times.
# 'mitta' letter 'a' appears 4 times.
# 'kiewa' letter 'a' appears 1 times.
# 'renmark' letter 'a' appears 1 times.
# 'faget' letter 'a' appears 1 times.
# 'posigrade' letter 'a' appears 1 times.
# 'heatshield' letter 'a' appears 1 times.
# 'farers' letter 'a' appears 1 times.
# 'hackert' letter 'a' appears 1 times.
# 'terentia' letter 'a' appears 1 times.
# 'tucca' letter 'a' appears 1 times.
# 'valgius' letter 'a' appears 1 times.
# 'octaviam' letter 'a' appears 1 times.
# 'mytikas' letter 'a' appears 2 times.
# 'mitikas' letter 'a' appears 3 times.
# 'samoset' letter 'a' appears 2 times.
# 'cancha' letter 'a' appears 1 times.
# 'rayada' letter 'a' appears 1 times.
# 'caillaux' letter 'a' appears 2 times.
# 'fawzia' letter 'a' appears 1 times.
# 'bratteli' letter 'a' appears 1 times.
# 'amoco' letter 'a' appears 2 times.
# 'portsall' letter 'a' appears 1 times.
# 'ismaning' letter 'a' appears 1 times.
# 'halabjah' letter 'a' appears 1 times.
# 'sandline' letter 'a' appears 2 times.
# 'ripudaman' letter 'a' appears 1 times.
# 'bagri' letter 'a' appears 1 times.
# 'kaisersberg' letter 'a' appears 2 times.
# 'acoluthus' letter 'a' appears 1 times.
# 'balcarce' letter 'a' appears 1 times.
# 'shibusawa' letter 'a' appears 1 times.
# 'harmel' letter 'a' appears 1 times.
# 'miramontes' letter 'a' appears 1 times.
# 'blasingame' letter 'a' appears 1 times.
# 'hnatyshyn' letter 'a' appears 1 times.
# 'bilardo' letter 'a' appears 1 times.
# 'austerely' letter 'a' appears 1 times.
# 'aethyrs' letter 'a' appears 1 times.
# 'samadhic' letter 'a' appears 1 times.
# 'interamna' letter 'a' appears 1 times.
# 'dysenteria' letter 'a' appears 1 times.
# 'harradine' letter 'a' appears 1 times.
# 'manoora' letter 'a' appears 1 times.
# 'nauruwire' letter 'a' appears 1 times.
# 'wadham' letter 'a' appears 2 times.
# 'odhams' letter 'a' appears 1 times.
# 'mikardo' letter 'a' appears 1 times.
# 'survivial' letter 'a' appears 1 times.
# 'reichsarbeitsdienst' letter 'a' appears 1 times.
# 'walpurgisnacht' letter 'a' appears 1 times.
# 'tanz' letter 'a' appears 1 times.
# 'calendimaggio' letter 'a' appears 1 times.
# 'collisionally' letter 'a' appears 1 times.
# 'decriminalise' letter 'a' appears 1 times.
# 'whitelaw' letter 'a' appears 1 times.
# 'ulsterisation' letter 'a' appears 1 times.
# 'fiach' letter 'a' appears 1 times.
# 'wanniski' letter 'a' appears 1 times.
# 'harked' letter 'a' appears 1 times.
# 'entrepreneurialism' letter 'a' appears 1 times.
# 'agusta' letter 'a' appears 2 times.
# 'workfare' letter 'a' appears 1 times.
# 'aircrash' letter 'a' appears 1 times.
# 'gaddafi' letter 'a' appears 2 times.
# 'rateable' letter 'a' appears 1 times.
# 'altria' letter 'a' appears 1 times.
# 'hairdressers' letter 'a' appears 1 times.
# 'blairism' letter 'a' appears 1 times.
# 'programe' letter 'a' appears 1 times.
# 'unionisation' letter 'a' appears 1 times.
# 'procapitalism' letter 'a' appears 1 times.
# 'imlay' letter 'a' appears 8 times.
# 'charnels' letter 'a' appears 1 times.
# 'annotating' letter 'a' appears 1 times.
# 'valperga' letter 'a' appears 1 times.
# 'renactment' letter 'a' appears 1 times.
# 'everina' letter 'a' appears 1 times.
# 'wollstonecrafts' letter 'a' appears 2 times.
# 'ladylike' letter 'a' appears 1 times.
# 'salzmann' letter 'a' appears 4 times.
# 'puerpal' letter 'a' appears 1 times.
# 'scarceness' letter 'a' appears 1 times.
# 'miseducated' letter 'a' appears 1 times.
# 'grandisson' letter 'a' appears 2 times.
# 'gehoorzaame' letter 'a' appears 2 times.
# 'moralisches' letter 'a' appears 1 times.
# 'elementarbuch' letter 'a' appears 1 times.
# 'insinuate' letter 'a' appears 1 times.
# 'coeducation' letter 'a' appears 1 times.
# 'deprave' letter 'a' appears 1 times.
# 'favret' letter 'a' appears 5 times.
# 'lyndall' letter 'a' appears 1 times.
# 'gubar' letter 'a' appears 1 times.
# 'vindications' letter 'a' appears 1 times.
# 'mesodermal' letter 'a' appears 1 times.
# 'sarcomeres' letter 'a' appears 2 times.
# 'brachii' letter 'a' appears 1 times.
# 'polymyalgia' letter 'a' appears 1 times.
# 'rheumatica' letter 'a' appears 1 times.
# 'arteritis' letter 'a' appears 1 times.
# 'rhabdomyolysis' letter 'a' appears 1 times.
# 'leiomyoma' letter 'a' appears 1 times.
# 'leiomyosarcoma' letter 'a' appears 1 times.
# 'rhabdomyoma' letter 'a' appears 1 times.
# 'masseter' letter 'a' appears 3 times.
# 'oota' letter 'a' appears 1 times.
# 'naruya' letter 'a' appears 1 times.
# 'saitou' letter 'a' appears 1 times.
# 'cellaring' letter 'a' appears 1 times.
# 'theakston' letter 'a' appears 1 times.
# 'campagning' letter 'a' appears 1 times.
# 'rottenhammer' letter 'a' appears 1 times.
# 'quinquatria' letter 'a' appears 6 times.
# 'hauptsatz' letter 'a' appears 1 times.
# 'mechanischen' letter 'a' appears 1 times.
# 'temperaturen' letter 'a' appears 1 times.
# 'wangenheimstra' letter 'a' appears 1 times.
# 'accomplishement' letter 'a' appears 1 times.
# 'harbingered' letter 'a' appears 1 times.
# 'annexionism' letter 'a' appears 1 times.
# 'notgemeinschaft' letter 'a' appears 1 times.
# 'hauptamt' letter 'a' appears 1 times.
# 'adlerschild' letter 'a' appears 1 times.
# 'planckia' letter 'a' appears 1 times.
# 'abdelhafid' letter 'a' appears 1 times.
# 'tabone' letter 'a' appears 1 times.
# 'astrud' letter 'a' appears 2 times.
# 'sajjad' letter 'a' appears 1 times.
# 'obadele' letter 'a' appears 1 times.
# 'barbadan' letter 'a' appears 1 times.
# 'nalick' letter 'a' appears 1 times.
# 'mutian' letter 'a' appears 1 times.
# 'heatter' letter 'a' appears 1 times.
# 'vijayan' letter 'a' appears 1 times.
# 'tezaab' letter 'a' appears 2 times.
# 'khalnayak' letter 'a' appears 2 times.
# 'anjaam' letter 'a' appears 2 times.
# 'nisha' letter 'a' appears 2 times.
# 'saroj' letter 'a' appears 1 times.
# 'areen' letter 'a' appears 1 times.
# 'rayan' letter 'a' appears 1 times.
# 'tumhare' letter 'a' appears 1 times.
# 'sanam' letter 'a' appears 1 times.
# 'chandramukhi' letter 'a' appears 1 times.
# 'lajja' letter 'a' appears 1 times.
# 'janki' letter 'a' appears 1 times.
# 'raaste' letter 'a' appears 1 times.
# 'neha' letter 'a' appears 1 times.
# 'pukar' letter 'a' appears 1 times.
# 'anjali' letter 'a' appears 1 times.
# 'aarzoo' letter 'a' appears 1 times.
# 'wajood' letter 'a' appears 1 times.
# 'apoorva' letter 'a' appears 1 times.
# 'dand' letter 'a' appears 1 times.
# 'mrityudand' letter 'a' appears 1 times.
# 'mohabbat' letter 'a' appears 1 times.
# 'mahaanta' letter 'a' appears 1 times.
# 'koyla' letter 'a' appears 1 times.
# 'gauri' letter 'a' appears 1 times.
# 'premgranth' letter 'a' appears 1 times.
# 'kajri' letter 'a' appears 1 times.
# 'rajkumari' letter 'a' appears 1 times.
# 'vishaka' letter 'a' appears 1 times.
# 'zameen' letter 'a' appears 1 times.
# 'yaarana' letter 'a' appears 1 times.
# 'lalita' letter 'a' appears 1 times.
# 'shikha' letter 'a' appears 1 times.
# 'premalayam' letter 'a' appears 1 times.
# 'aansoo' letter 'a' appears 1 times.
# 'angaray' letter 'a' appears 1 times.
# 'sahibaan' letter 'a' appears 2 times.
# 'aashiq' letter 'a' appears 1 times.
# 'dharavi' letter 'a' appears 2 times.
# 'dreamgirl' letter 'a' appears 1 times.
# 'deewane' letter 'a' appears 1 times.
# 'shivangi' letter 'a' appears 1 times.
# 'juaa' letter 'a' appears 1 times.
# 'jamai' letter 'a' appears 1 times.
# 'rekha' letter 'a' appears 1 times.
# 'seema' letter 'a' appears 1 times.
# 'jhari' letter 'a' appears 1 times.
# 'prahaar' letter 'a' appears 1 times.
# 'saajan' letter 'a' appears 1 times.
# 'pratikaar' letter 'a' appears 1 times.
# 'deewana' letter 'a' appears 1 times.
# 'diwana' letter 'a' appears 1 times.
# 'mujhsa' letter 'a' appears 1 times.
# 'izzatdaar' letter 'a' appears 1 times.
# 'khilaaf' letter 'a' appears 1 times.
# 'sweta' letter 'a' appears 1 times.
# 'kanhaiya' letter 'a' appears 1 times.
# 'thanedaar' letter 'a' appears 1 times.
# 'sailaab' letter 'a' appears 1 times.
# 'sushma' letter 'a' appears 1 times.
# 'jeevan' letter 'a' appears 1 times.
# 'sangharsh' letter 'a' appears 1 times.
# 'sangram' letter 'a' appears 2 times.
# 'kanoon' letter 'a' appears 1 times.
# 'parinda' letter 'a' appears 1 times.
# 'lakhan' letter 'a' appears 1 times.
# 'divya' letter 'a' appears 1 times.
# 'anth' letter 'a' appears 1 times.
# 'pratigyaa' letter 'a' appears 1 times.
# 'ilaaka' letter 'a' appears 1 times.
# 'vidya' letter 'a' appears 2 times.
# 'khatron' letter 'a' appears 1 times.
# 'khiladi' letter 'a' appears 1 times.
# 'dayavan' letter 'a' appears 1 times.
# 'awara' letter 'a' appears 1 times.
# 'baap' letter 'a' appears 1 times.
# 'hifazat' letter 'a' appears 1 times.
# 'abodh' letter 'a' appears 1 times.
# 'lajaa' letter 'a' appears 1 times.
# 'sansui' letter 'a' appears 1 times.
# 'maharastrian' letter 'a' appears 1 times.
# 'trichloroethane' letter 'a' appears 1 times.
# 'stolarski' letter 'a' appears 1 times.
# 'privotal' letter 'a' appears 1 times.
# 'ausaid' letter 'a' appears 1 times.
# 'chloroflurocarbons' letter 'a' appears 1 times.
# 'scarea' letter 'a' appears 1 times.
# 'petitcodiac' letter 'a' appears 10 times.
# 'shediac' letter 'a' appears 3 times.
# 'parlee' letter 'a' appears 1 times.
# 'eatons' letter 'a' appears 1 times.
# 'chiac' letter 'a' appears 1 times.
# 'escaouette' letter 'a' appears 2 times.
# 'hubcap' letter 'a' appears 1 times.
# 'aout' letter 'a' appears 1 times.
# 'ballfields' letter 'a' appears 1 times.
# 'gmia' letter 'a' appears 2 times.
# 'purolator' letter 'a' appears 1 times.
# 'codiac' letter 'a' appears 1 times.
# 'kouchibouguac' letter 'a' appears 1 times.
# 'rocksare' letter 'a' appears 1 times.
# 'jourimain' letter 'a' appears 1 times.
# 'sagouine' letter 'a' appears 1 times.
# 'secondaire' letter 'a' appears 2 times.
# 'cbaf' letter 'a' appears 1 times.
# 'cbal' letter 'a' appears 1 times.
# 'cita' letter 'a' appears 1 times.
# 'medavie' letter 'a' appears 1 times.
# 'asurion' letter 'a' appears 1 times.
# 'oao' letter 'a' appears 1 times.
# 'nanoptix' letter 'a' appears 1 times.
# 'majesta' letter 'a' appears 1 times.
# 'memramcook' letter 'a' appears 1 times.
# 'monctonians' letter 'a' appears 1 times.
# 'malenfant' letter 'a' appears 1 times.
# 'houlahan' letter 'a' appears 1 times.
# 'playright' letter 'a' appears 1 times.
# 'rheal' letter 'a' appears 1 times.
# 'bastarache' letter 'a' appears 1 times.
# 'chiasson' letter 'a' appears 1 times.
# 'breau' letter 'a' appears 1 times.
# 'monctonlocals' letter 'a' appears 1 times.
# 'malcev' letter 'a' appears 1 times.
# 'elementarily' letter 'a' appears 1 times.
# 'axiomatizable' letter 'a' appears 1 times.
# 'hyperreals' letter 'a' appears 1 times.
# 'stylizations' letter 'a' appears 1 times.
# 'ahabs' letter 'a' appears 1 times.
# 'leviathans' letter 'a' appears 1 times.
# 'harpooners' letter 'a' appears 1 times.
# 'harpooner' letter 'a' appears 6 times.
# 'tashtego' letter 'a' appears 2 times.
# 'daggoo' letter 'a' appears 2 times.
# 'fedallah' letter 'a' appears 1 times.
# 'funereally' letter 'a' appears 1 times.
# 'riddance' letter 'a' appears 1 times.
# 'achab' letter 'a' appears 1 times.
# 'bonpart' letter 'a' appears 1 times.
# 'rakhnam' letter 'a' appears 1 times.
# 'arcwhale' letter 'a' appears 1 times.
# 'mapple' letter 'a' appears 1 times.
# 'seabeast' letter 'a' appears 1 times.
# 'icthyosaur' letter 'a' appears 1 times.
# 'pagemaster' letter 'a' appears 1 times.
# 'adama' letter 'a' appears 1 times.
# 'philosophicae' letter 'a' appears 1 times.
# 'analitiche' letter 'a' appears 1 times.
# 'antelmy' letter 'a' appears 1 times.
# 'maseres' letter 'a' appears 1 times.
# 'versiera' letter 'a' appears 2 times.
# 'versoria' letter 'a' appears 1 times.
# 'avversiera' letter 'a' appears 1 times.
# 'bruja' letter 'a' appears 1 times.
# 'guapore' letter 'a' appears 2 times.
# 'mamor' letter 'a' appears 4 times.
# 'guajar' letter 'a' appears 2 times.
# 'baures' letter 'a' appears 1 times.
# 'itonama' letter 'a' appears 1 times.
# 'mayutata' letter 'a' appears 1 times.
# 'abun' letter 'a' appears 1 times.
# 'tupinambaranas' letter 'a' appears 1 times.
# 'chachapoyas' letter 'a' appears 2 times.
# 'leymebamba' letter 'a' appears 1 times.
# 'marapon' letter 'a' appears 1 times.
# 'imasa' letter 'a' appears 1 times.
# 'chunchunga' letter 'a' appears 1 times.
# 'guaracayo' letter 'a' appears 1 times.
# 'loxa' letter 'a' appears 1 times.
# 'aquarum' letter 'a' appears 1 times.
# 'parou' letter 'a' appears 1 times.
# 'pionerskaya' letter 'a' appears 1 times.
# 'maksimilianovich' letter 'a' appears 1 times.
# 'kanawa' letter 'a' appears 3 times.
# 'shaukat' letter 'a' appears 1 times.
# 'knetemann' letter 'a' appears 1 times.
# 'rstad' letter 'a' appears 1 times.
# 'jacklyn' letter 'a' appears 1 times.
# 'tari' letter 'a' appears 1 times.
# 'pedrarias' letter 'a' appears 1 times.
# 'zbaraski' letter 'a' appears 1 times.
# 'kaiulani' letter 'a' appears 1 times.
# 'slapsie' letter 'a' appears 1 times.
# 'laetare' letter 'a' appears 3 times.
# 'cusulima' letter 'a' appears 1 times.
# 'cusuhma' letter 'a' appears 1 times.
# 'miazal' letter 'a' appears 1 times.
# 'ashmont' letter 'a' appears 6 times.
# 'mattapan' letter 'a' appears 5 times.
# 'arborway' letter 'a' appears 6 times.
# 'stationas' letter 'a' appears 1 times.
# 'prepayment' letter 'a' appears 2 times.
# 'savin' letter 'a' appears 1 times.
# 'adajcent' letter 'a' appears 1 times.
# 'badtransit' letter 'a' appears 1 times.
# 'netransit' letter 'a' appears 1 times.
# 'tetraquark' letter 'a' appears 1 times.
# 'antiup' letter 'a' appears 1 times.
# 'antidown' letter 'a' appears 1 times.
# 'intranuclear' letter 'a' appears 1 times.
# 'hadrodynamics' letter 'a' appears 1 times.
# 'quarkonium' letter 'a' appears 1 times.
# 'pseudoscalars' letter 'a' appears 2 times.
# 'hadwiger' letter 'a' appears 1 times.
# 'reitwagen' letter 'a' appears 2 times.
# 'brazed' letter 'a' appears 1 times.
# 'antilock' letter 'a' appears 2 times.
# 'trailbraking' letter 'a' appears 2 times.
# 'roadracing' letter 'a' appears 1 times.
# 'sidewall' letter 'a' appears 1 times.
# 'valving' letter 'a' appears 1 times.
# 'carburation' letter 'a' appears 1 times.
# 'manufacuturers' letter 'a' appears 1 times.
# 'hondabbs' letter 'a' appears 1 times.
# 'katriders' letter 'a' appears 1 times.
# 'hondas' letter 'a' appears 1 times.
# 'motorrad' letter 'a' appears 1 times.
# 'bmwmoa' letter 'a' appears 1 times.
# 'bmwra' letter 'a' appears 1 times.
# 'cartograms' letter 'a' appears 1 times.
# 'mapmachine' letter 'a' appears 1 times.
# 'maptech' letter 'a' appears 1 times.
# 'hargrett' letter 'a' appears 1 times.
# 'webinterface' letter 'a' appears 1 times.
# 'abmap' letter 'a' appears 1 times.
# 'routenplaner' letter 'a' appears 1 times.
# 'fayol' letter 'a' appears 1 times.
# 'ordwat' letter 'a' appears 1 times.
# 'tead' letter 'a' appears 1 times.
# 'argyris' letter 'a' appears 1 times.
# 'goldratt' letter 'a' appears 1 times.
# 'sugarshack' letter 'a' appears 1 times.
# 'saccharum' letter 'a' appears 1 times.
# 'sugarwoods' letter 'a' appears 1 times.
# 'sugarhouse' letter 'a' appears 1 times.
# 'cabanes' letter 'a' appears 1 times.
# 'walling' letter 'a' appears 3 times.
# 'sugaring' letter 'a' appears 3 times.
# 'defoamer' letter 'a' appears 1 times.
# 'objectional' letter 'a' appears 1 times.
# 'subgrades' letter 'a' appears 1 times.
# 'milkshakes' letter 'a' appears 1 times.
# 'poteau' letter 'a' appears 1 times.
# 'mattay' letter 'a' appears 2 times.
# 'mattany' letter 'a' appears 1 times.
# 'mattayy' letter 'a' appears 1 times.
# 'algie' letter 'a' appears 1 times.
# 'makros' letter 'a' appears 1 times.
# 'bazn' letter 'a' appears 1 times.
# 'maaori' letter 'a' appears 1 times.
# 'aori' letter 'a' appears 1 times.
# 'exhorbitant' letter 'a' appears 1 times.
# 'chequable' letter 'a' appears 1 times.
# 'masajid' letter 'a' appears 1 times.
# 'moseak' letter 'a' appears 1 times.
# 'sajad' letter 'a' appears 1 times.
# 'prostrations' letter 'a' appears 1 times.
# 'tarawih' letter 'a' appears 1 times.
# 'janazah' letter 'a' appears 1 times.
# 'iftars' letter 'a' appears 1 times.
# 'entryways' letter 'a' appears 1 times.
# 'khutbah' letter 'a' appears 1 times.
# 'sajid' letter 'a' appears 1 times.
# 'islamicfinder' letter 'a' appears 1 times.
# 'molcular' letter 'a' appears 1 times.
# 'reliastar' letter 'a' appears 1 times.
# 'shumeikai' letter 'a' appears 1 times.
# 'cevahir' letter 'a' appears 1 times.
# 'belas' letter 'a' appears 1 times.
# 'machico' letter 'a' appears 4 times.
# 'cani' letter 'a' appears 3 times.
# 'baleira' letter 'a' appears 2 times.
# 'mauretanian' letter 'a' appears 1 times.
# 'machim' letter 'a' appears 1 times.
# 'arfet' letter 'a' appears 1 times.
# 'levadas' letter 'a' appears 4 times.
# 'caldeiro' letter 'a' appears 1 times.
# 'caldeir' letter 'a' appears 1 times.
# 'deserta' letter 'a' appears 1 times.
# 'selvagem' letter 'a' appears 2 times.
# 'pequena' letter 'a' appears 1 times.
# 'selvagens' letter 'a' appears 1 times.
# 'desertas' letter 'a' appears 1 times.
# 'armalite' letter 'a' appears 11 times.
# 'picatinny' letter 'a' appears 11 times.
# 'alclad' letter 'a' appears 1 times.
# 'conarc' letter 'a' appears 3 times.
# 'airbursting' letter 'a' appears 1 times.
# 'diemaco' letter 'a' appears 3 times.
# 'handguards' letter 'a' appears 4 times.
# 'latteral' letter 'a' appears 1 times.
# 'parkerized' letter 'a' appears 1 times.
# 'kac' letter 'a' appears 3 times.
# 'artillerymen' letter 'a' appears 1 times.
# 'oceanside' letter 'a' appears 1 times.
# 'halsted' letter 'a' appears 1 times.
# 'operationandcycleoffunctioningtf' letter 'a' appears 1 times.
# 'gya' letter 'a' appears 1 times.
# 'sakini' letter 'a' appears 1 times.
# 'sacheen' letter 'a' appears 1 times.
# 'littlefeather' letter 'a' appears 1 times.
# 'kashfi' letter 'a' appears 2 times.
# 'movita' letter 'a' appears 2 times.
# 'tarita' letter 'a' appears 2 times.
# 'teriipia' letter 'a' appears 3 times.
# 'galella' letter 'a' appears 2 times.
# 'corval' letter 'a' appears 1 times.
# 'maimiti' letter 'a' appears 1 times.
# 'raiatua' letter 'a' appears 1 times.
# 'raoni' letter 'a' appears 1 times.
# 'brandoland' letter 'a' appears 1 times.
# 'interdiscplinary' letter 'a' appears 1 times.
# 'barotropic' letter 'a' appears 1 times.
# 'allmetsat' letter 'a' appears 1 times.
# 'automounting' letter 'a' appears 1 times.
# 'beggiatoa' letter 'a' appears 1 times.
# 'winogradsky' letter 'a' appears 2 times.
# 'microbially' letter 'a' appears 1 times.
# 'organsisms' letter 'a' appears 1 times.
# 'biotechnologically' letter 'a' appears 1 times.
# 'martinko' letter 'a' appears 1 times.
# 'regardles' letter 'a' appears 1 times.
# 'aldohexoses' letter 'a' appears 1 times.
# 'aldose' letter 'a' appears 2 times.
# 'hemiacetals' letter 'a' appears 2 times.
# 'hemiketals' letter 'a' appears 2 times.
# 'glycolaldehyde' letter 'a' appears 1 times.
# 'arabinose' letter 'a' appears 1 times.
# 'allose' letter 'a' appears 1 times.
# 'altrose' letter 'a' appears 1 times.
# 'talose' letter 'a' appears 1 times.
# 'tagatose' letter 'a' appears 1 times.
# 'mannoheptulose' letter 'a' appears 1 times.
# 'octonate' letter 'a' appears 1 times.
# 'sialose' letter 'a' appears 1 times.
# 'ketals' letter 'a' appears 1 times.
# 'ferrat' letter 'a' appears 8 times.
# 'sofinsa' letter 'a' appears 1 times.
# 'caesurae' letter 'a' appears 1 times.
# 'anapest' letter 'a' appears 1 times.
# 'moras' letter 'a' appears 1 times.
# 'tristia' letter 'a' appears 1 times.
# 'hendecasyllabic' letter 'a' appears 2 times.
# 'adonic' letter 'a' appears 1 times.
# 'superare' letter 'a' appears 1 times.
# 'spectat' letter 'a' appears 1 times.
# 'unsandalled' letter 'a' appears 1 times.
# 'septenary' letter 'a' appears 3 times.
# 'octosyllable' letter 'a' appears 2 times.
# 'heptasyllables' letter 'a' appears 1 times.
# 'novenary' letter 'a' appears 1 times.
# 'accentations' letter 'a' appears 1 times.
# 'quanititative' letter 'a' appears 1 times.
# 'mashaan' letter 'a' appears 1 times.
# 'annakhil' letter 'a' appears 1 times.
# 'hanjourmoqed' letter 'a' appears 1 times.
# 'risograph' letter 'a' appears 1 times.
# 'xerography' letter 'a' appears 1 times.
# 'risographs' letter 'a' appears 1 times.
# 'autographic' letter 'a' appears 2 times.
# 'zaccato' letter 'a' appears 1 times.
# 'roneograph' letter 'a' appears 1 times.
# 'mimeographs' letter 'a' appears 1 times.
# 'mimeographical' letter 'a' appears 1 times.
# 'mimeogram' letter 'a' appears 1 times.
# 'presolar' letter 'a' appears 1 times.
# 'achondrites' letter 'a' appears 2 times.
# 'sylacauga' letter 'a' appears 1 times.
# 'sayh' letter 'a' appears 1 times.
# 'uhaymir' letter 'a' appears 1 times.
# 'alin' letter 'a' appears 2 times.
# 'baetylus' letter 'a' appears 2 times.
# 'aerolite' letter 'a' appears 1 times.
# 'meteoritical' letter 'a' appears 1 times.
# 'hoba' letter 'a' appears 1 times.
# 'megaword' letter 'a' appears 1 times.
# 'megalo' letter 'a' appears 1 times.
# 'televisiva' letter 'a' appears 1 times.
# 'megavisi' letter 'a' appears 1 times.
# 'ynary' letter 'a' appears 1 times.
# 'plazynski' letter 'a' appears 1 times.
# 'kacper' letter 'a' appears 1 times.
# 'hoglan' letter 'a' appears 1 times.
# 'sibilancy' letter 'a' appears 1 times.
# 'articulator' letter 'a' appears 1 times.
# 'resonants' letter 'a' appears 2 times.
# 'velaric' letter 'a' appears 1 times.
# 'mostaganem' letter 'a' appears 3 times.
# 'microatx' letter 'a' appears 2 times.
# 'antec' letter 'a' appears 1 times.
# 'flexatx' letter 'a' appears 1 times.
# 'cartoccia' letter 'a' appears 1 times.
# 'scoltura' letter 'a' appears 1 times.
# 'mannersist' letter 'a' appears 1 times.
# 'arcimboldo' letter 'a' appears 1 times.
# 'rondanini' letter 'a' appears 1 times.
# 'caprarola' letter 'a' appears 1 times.
# 'franzsepp' letter 'a' appears 1 times.
# 'samille' letter 'a' appears 1 times.
# 'monicagate' letter 'a' appears 2 times.
# 'berlant' letter 'a' appears 1 times.
# 'manometer' letter 'a' appears 11 times.
# 'manometers' letter 'a' appears 2 times.
# 'caston' letter 'a' appears 17 times.
# 'nanasawa' letter 'a' appears 1 times.
# 'megagamers' letter 'a' appears 2 times.
# 'saurians' letter 'a' appears 1 times.
# 'predesignated' letter 'a' appears 1 times.
# 'tohya' letter 'a' appears 1 times.
# 'restauraunt' letter 'a' appears 1 times.
# 'acessory' letter 'a' appears 1 times.
# 'admistrators' letter 'a' appears 1 times.
# 'ironcat' letter 'a' appears 2 times.
# 'bookscan' letter 'a' appears 1 times.
# 'megagear' letter 'a' appears 5 times.
# 'fredart' letter 'a' appears 1 times.
# 'rcaston' letter 'a' appears 1 times.
# 'wascally' letter 'a' appears 1 times.
# 'wabbits' letter 'a' appears 1 times.
# 'garlandia' letter 'a' appears 4 times.
# 'mensurabili' letter 'a' appears 1 times.
# 'mensurabilis' letter 'a' appears 1 times.
# 'mensural' letter 'a' appears 3 times.
# 'mensuration' letter 'a' appears 1 times.
# 'attributory' letter 'a' appears 1 times.
# 'afflighemensis' letter 'a' appears 1 times.
# 'gallicus' letter 'a' appears 1 times.
# 'marchettus' letter 'a' appears 1 times.
# 'enchiriadis' letter 'a' appears 1 times.
# 'calixtinus' letter 'a' appears 1 times.
# 'hucbald' letter 'a' appears 1 times.
# 'balbulus' letter 'a' appears 1 times.
# 'discant' letter 'a' appears 7 times.
# 'melismas' letter 'a' appears 1 times.
# 'clausulae' letter 'a' appears 1 times.
# 'clausula' letter 'a' appears 2 times.
# 'clasulae' letter 'a' appears 3 times.
# 'huelgas' letter 'a' appears 1 times.
# 'innagurated' letter 'a' appears 1 times.
# 'petronian' letter 'a' appears 2 times.
# 'palou' letter 'a' appears 1 times.
# 'arnaut' letter 'a' appears 1 times.
# 'giraut' letter 'a' appears 1 times.
# 'marcabru' letter 'a' appears 1 times.
# 'bernart' letter 'a' appears 1 times.
# 'ventadorn' letter 'a' appears 1 times.
# 'jaufr' letter 'a' appears 1 times.
# 'niedhart' letter 'a' appears 1 times.
# 'reuenthal' letter 'a' appears 1 times.
# 'fauvel' letter 'a' appears 2 times.
# 'solage' letter 'a' appears 1 times.
# 'cantalina' letter 'a' appears 1 times.
# 'disperate' letter 'a' appears 1 times.
# 'ballata' letter 'a' appears 1 times.
# 'landini' letter 'a' appears 1 times.
# 'gherardello' letter 'a' appears 1 times.
# 'tenorista' letter 'a' appears 1 times.
# 'bartolino' letter 'a' appears 1 times.
# 'masini' letter 'a' appears 1 times.
# 'manneristic' letter 'a' appears 1 times.
# 'augenmusik' letter 'a' appears 1 times.
# 'baude' letter 'a' appears 2 times.
# 'anthonello' letter 'a' appears 1 times.
# 'ciconia' letter 'a' appears 1 times.
# 'faburden' letter 'a' appears 1 times.
# 'fauxbordon' letter 'a' appears 1 times.
# 'lantins' letter 'a' appears 1 times.
# 'ardis' letter 'a' appears 1 times.
# 'seay' letter 'a' appears 1 times.
# 'icrowave' letter 'a' appears 3 times.
# 'olecular' letter 'a' appears 2 times.
# 'masing' letter 'a' appears 3 times.
# 'superradiant' letter 'a' appears 1 times.
# 'grasers' letter 'a' appears 1 times.
# 'xasers' letter 'a' appears 1 times.
# 'uvasers' letter 'a' appears 1 times.
# 'irasers' letter 'a' appears 1 times.
# 'rasers' letter 'a' appears 1 times.
# 'charric' letter 'a' appears 1 times.
# 'artistico' letter 'a' appears 1 times.
# 'mediatheque' letter 'a' appears 1 times.
# 'villeurbanne' letter 'a' appears 1 times.
# 'sfmoma' letter 'a' appears 1 times.
# 'vimercate' letter 'a' appears 1 times.
# 'antonivs' letter 'a' appears 1 times.
# 'julias' letter 'a' appears 1 times.
# 'catilinarian' letter 'a' appears 1 times.
# 'gabinius' letter 'a' appears 1 times.
# 'auletes' letter 'a' appears 1 times.
# 'bononia' letter 'a' appears 1 times.
# 'reipublicae' letter 'a' appears 1 times.
# 'constituendae' letter 'a' appears 1 times.
# 'titia' letter 'a' appears 1 times.
# 'fadia' letter 'a' appears 2 times.
# 'hybrida' letter 'a' appears 1 times.
# 'dolabella' letter 'a' appears 1 times.
# 'antyllus' letter 'a' appears 1 times.
# 'grecians' letter 'a' appears 1 times.
# 'gardthausen' letter 'a' appears 1 times.
# 'drumann' letter 'a' appears 1 times.
# 'marci' letter 'a' appears 2 times.
# 'ccarm' letter 'a' appears 1 times.
# 'crerand' letter 'a' appears 1 times.
# 'mcclair' letter 'a' appears 1 times.
# 'assulting' letter 'a' appears 1 times.
# 'comapany' letter 'a' appears 1 times.
# 'mancunians' letter 'a' appears 1 times.
# 'imusa' letter 'a' appears 2 times.
# 'ebanks' letter 'a' appears 1 times.
# 'fangzhuo' letter 'a' appears 1 times.
# 'souleymane' letter 'a' appears 1 times.
# 'mamam' letter 'a' appears 1 times.
# 'manutdweb' letter 'a' appears 1 times.
# 'redcafe' letter 'a' appears 1 times.
# 'footymania' letter 'a' appears 1 times.
# 'devilpage' letter 'a' appears 1 times.
# 'globalview' letter 'a' appears 2 times.
# 'fundementals' letter 'a' appears 1 times.
# 'bwsmagnifier' letter 'a' appears 1 times.
# 'landino' letter 'a' appears 1 times.
# 'chalkondyles' letter 'a' appears 1 times.
# 'marsilius' letter 'a' appears 1 times.
# 'valdarno' letter 'a' appears 1 times.
# 'argyropoulos' letter 'a' appears 1 times.
# 'platonica' letter 'a' appears 1 times.
# 'immortalitate' letter 'a' appears 1 times.
# 'aliveness' letter 'a' appears 1 times.
# 'kaske' letter 'a' appears 2 times.
# 'renaissanceastrology' letter 'a' appears 1 times.
# 'nanos' letter 'a' appears 6 times.
# 'homeodomain' letter 'a' appears 1 times.
# 'zygotically' letter 'a' appears 2 times.
# 'parasegments' letter 'a' appears 2 times.
# 'syncytial' letter 'a' appears 4 times.
# 'blastoderm' letter 'a' appears 7 times.
# 'parasegment' letter 'a' appears 1 times.
# 'extracelluar' letter 'a' appears 1 times.
# 'antennapedia' letter 'a' appears 5 times.
# 'proboscipedia' letter 'a' appears 1 times.
# 'bithorax' letter 'a' appears 1 times.
# 'tagmosis' letter 'a' appears 1 times.
# 'monochloroacetic' letter 'a' appears 1 times.
# 'chlorinating' letter 'a' appears 1 times.
# 'organizatorial' letter 'a' appears 1 times.
# 'crucifera' letter 'a' appears 1 times.
# 'fraternitas' letter 'a' appears 1 times.
# 'thanateros' letter 'a' appears 1 times.
# 'martiniste' letter 'a' appears 1 times.
# 'tamimi' letter 'a' appears 1 times.
# 'salafists' letter 'a' appears 1 times.
# 'muwahhidun' letter 'a' appears 1 times.
# 'ghannam' letter 'a' appears 1 times.
# 'unwan' letter 'a' appears 1 times.
# 'uyayna' letter 'a' appears 2 times.
# 'hamidi' letter 'a' appears 1 times.
# 'talab' letter 'a' appears 1 times.
# 'ahamd' letter 'a' appears 1 times.
# 'azhari' letter 'a' appears 1 times.
# 'tandatawi' letter 'a' appears 5 times.
# 'dalala' letter 'a' appears 1 times.
# 'djahala' letter 'a' appears 1 times.
# 'shahir' letter 'a' appears 1 times.
# 'khitab' letter 'a' appears 1 times.
# 'dalalat' letter 'a' appears 2 times.
# 'wadjh' letter 'a' appears 1 times.
# 'capaigns' letter 'a' appears 1 times.
# 'whahabi' letter 'a' appears 1 times.
# 'traboulsi' letter 'a' appears 1 times.
# 'samer' letter 'a' appears 1 times.
# 'taymiyyah' letter 'a' appears 1 times.
# 'addressbook' letter 'a' appears 1 times.
# 'accessorizing' letter 'a' appears 1 times.
# 'cameraphones' letter 'a' appears 1 times.
# 'cameraphone' letter 'a' appears 1 times.
# 'photosharing' letter 'a' appears 1 times.
# 'ectaco' letter 'a' appears 1 times.
# 'kaleido' letter 'a' appears 1 times.
# 'neomedia' letter 'a' appears 1 times.
# 'paperclick' letter 'a' appears 1 times.
# 'scanbuy' letter 'a' appears 1 times.
# 'jumptag' letter 'a' appears 1 times.
# 'loizeau' letter 'a' appears 1 times.
# 'felica' letter 'a' appears 1 times.
# 'startac' letter 'a' appears 1 times.
# 'handgehaltenes' letter 'a' appears 1 times.
# 'handie' letter 'a' appears 1 times.
# 'dianhua' letter 'a' appears 1 times.
# 'handphone' letter 'a' appears 1 times.
# 'bluedating' letter 'a' appears 1 times.
# 'wabanaki' letter 'a' appears 1 times.
# 'sagadahock' letter 'a' appears 1 times.
# 'baldacci' letter 'a' appears 2 times.
# 'piscataquis' letter 'a' appears 1 times.
# 'pemaquid' letter 'a' appears 1 times.
# 'boothbay' letter 'a' appears 1 times.
# 'mainers' letter 'a' appears 1 times.
# 'midcoast' letter 'a' appears 1 times.
# 'downeast' letter 'a' appears 1 times.
# 'mainetoday' letter 'a' appears 1 times.
# 'mesda' letter 'a' appears 1 times.
# 'baucus' letter 'a' appears 2 times.
# 'undammed' letter 'a' appears 1 times.
# 'absaroka' letter 'a' appears 1 times.
# 'beartooth' letter 'a' appears 2 times.
# 'clarks' letter 'a' appears 1 times.
# 'asters' letter 'a' appears 1 times.
# 'sagebrush' letter 'a' appears 2 times.
# 'homesteaders' letter 'a' appears 1 times.
# 'kalispell' letter 'a' appears 3 times.
# 'montanans' letter 'a' appears 1 times.
# 'blacktail' letter 'a' appears 1 times.
# 'lewisia' letter 'a' appears 1 times.
# 'blackspotted' letter 'a' appears 1 times.
# 'techranch' letter 'a' appears 1 times.
# 'eamt' letter 'a' appears 2 times.
# 'interlingual' letter 'a' appears 1 times.
# 'alpac' letter 'a' appears 2 times.
# 'taum' letter 'a' appears 1 times.
# 'patrans' letter 'a' appears 1 times.
# 'trados' letter 'a' appears 1 times.
# 'eurotra' letter 'a' appears 1 times.
# 'apertium' letter 'a' appears 1 times.
# 'opentrad' letter 'a' appears 1 times.
# 'linguaphile' letter 'a' appears 1 times.
# 'carabao' letter 'a' appears 1 times.
# 'libtranslate' letter 'a' appears 1 times.
# 'ciyasoft' letter 'a' appears 1 times.
# 'sakhr' letter 'a' appears 1 times.
# 'apptek' letter 'a' appears 1 times.
# 'qwika' letter 'a' appears 1 times.
# 'amta' letter 'a' appears 1 times.
# 'davendig' letter 'a' appears 1 times.
# 'timars' letter 'a' appears 1 times.
# 'timariots' letter 'a' appears 1 times.
# 'kazasker' letter 'a' appears 1 times.
# 'karamanid' letter 'a' appears 3 times.
# 'candaroglu' letter 'a' appears 1 times.
# 'chamurli' letter 'a' appears 1 times.
# 'saracenie' letter 'a' appears 1 times.
# 'beyazit' letter 'a' appears 2 times.
# 'hononrable' letter 'a' appears 1 times.
# 'defterdar' letter 'a' appears 1 times.
# 'chancelor' letter 'a' appears 1 times.
# 'ottaman' letter 'a' appears 1 times.
# 'paleaogus' letter 'a' appears 1 times.
# 'azeb' letter 'a' appears 1 times.
# 'germian' letter 'a' appears 1 times.
# 'karamanids' letter 'a' appears 1 times.
# 'jalowaz' letter 'a' appears 1 times.
# 'sporatic' letter 'a' appears 1 times.
# 'referance' letter 'a' appears 1 times.
# 'baffo' letter 'a' appears 1 times.
# 'valide' letter 'a' appears 2 times.
# 'safiye' letter 'a' appears 2 times.
# 'erlau' letter 'a' appears 1 times.
# 'topkap' letter 'a' appears 1 times.
# 'seishinsha' letter 'a' appears 1 times.
# 'harumichi' letter 'a' appears 1 times.
# 'deunan' letter 'a' appears 1 times.
# 'seska' letter 'a' appears 1 times.
# 'funya' letter 'a' appears 1 times.
# 'kintalion' letter 'a' appears 1 times.
# 'opional' letter 'a' appears 1 times.
# 'amazoness' letter 'a' appears 1 times.
# 'arice' letter 'a' appears 1 times.
# 'kaizokuban' letter 'a' appears 2 times.
# 'atpas' letter 'a' appears 1 times.
# 'kitakubo' letter 'a' appears 1 times.
# 'katayama' letter 'a' appears 1 times.
# 'takaaki' letter 'a' appears 1 times.
# 'ishiyama' letter 'a' appears 1 times.
# 'mashimo' letter 'a' appears 1 times.
# 'aramaki' letter 'a' appears 1 times.
# 'kamiyama' letter 'a' appears 2 times.
# 'yarudora' letter 'a' appears 1 times.
# 'sampaguita' letter 'a' appears 1 times.
# 'hyperpage' letter 'a' appears 2 times.
# 'musicalsaw' letter 'a' appears 1 times.
# 'sandvik' letter 'a' appears 1 times.
# 'paruz' letter 'a' appears 2 times.
# 'bytestream' letter 'a' appears 1 times.
# 'aftertouch' letter 'a' appears 3 times.
# 'multitimbral' letter 'a' appears 1 times.
# 'soundcards' letter 'a' appears 1 times.
# 'amei' letter 'a' appears 3 times.
# 'cnmat' letter 'a' appears 1 times.
# 'octapad' letter 'a' appears 1 times.
# 'portamento' letter 'a' appears 1 times.
# 'microassembler' letter 'a' appears 3 times.
# 'microprogrammer' letter 'a' appears 1 times.
# 'microarchitectures' letter 'a' appears 2 times.
# 'micromachine' letter 'a' appears 2 times.
# 'microassembly' letter 'a' appears 1 times.
# 'poopulation' letter 'a' appears 1 times.
# 'formalises' letter 'a' appears 2 times.
# 'abstraite' letter 'a' appears 1 times.
# 'megaphone' letter 'a' appears 1 times.
# 'burago' letter 'a' appears 2 times.
# 'crysomonads' letter 'a' appears 1 times.
# 'chloromonads' letter 'a' appears 1 times.
# 'prasinomonads' letter 'a' appears 1 times.
# 'silicoflagellates' letter 'a' appears 1 times.
# 'dinoflaggelates' letter 'a' appears 1 times.
# 'chaetognaths' letter 'a' appears 1 times.
# 'urochordates' letter 'a' appears 1 times.
# 'polychaetes' letter 'a' appears 1 times.
# 'sargassum' letter 'a' appears 1 times.
# 'seagrasses' letter 'a' appears 1 times.
# 'eelgrass' letter 'a' appears 1 times.
# 'zostera' letter 'a' appears 1 times.
# 'turtlegrass' letter 'a' appears 1 times.
# 'thalassia' letter 'a' appears 1 times.
# 'cordgrass' letter 'a' appears 1 times.
# 'plathyhelminthes' letter 'a' appears 1 times.
# 'echiura' letter 'a' appears 1 times.
# 'anemonefish' letter 'a' appears 1 times.
# 'soleidae' letter 'a' appears 1 times.
# 'nicholai' letter 'a' appears 1 times.
# 'maklai' letter 'a' appears 1 times.
# 'seaturtle' letter 'a' appears 1 times.
# 'marinebiology' letter 'a' appears 1 times.
# 'brainix' letter 'a' appears 1 times.
# 'nanokernel' letter 'a' appears 3 times.
# 'trimarans' letter 'a' appears 3 times.
# 'amarylis' letter 'a' appears 1 times.
# 'powerboats' letter 'a' appears 1 times.
# 'defination' letter 'a' appears 1 times.
# 'boatbuilders' letter 'a' appears 1 times.
# 'liferaft' letter 'a' appears 1 times.
# 'pajot' letter 'a' appears 1 times.
# 'orma' letter 'a' appears 1 times.
# 'catsailor' letter 'a' appears 1 times.
# 'ubbthreads' letter 'a' appears 1 times.
# 'cruisincats' letter 'a' appears 2 times.
# 'supercatamarans' letter 'a' appears 1 times.
# 'tandydos' letter 'a' appears 1 times.
# 'disassemble' letter 'a' appears 1 times.
# 'downloadpage' letter 'a' appears 1 times.
# 'meriadog' letter 'a' appears 1 times.
# 'meryasek' letter 'a' appears 1 times.
# 'meriadek' letter 'a' appears 1 times.
# 'meridiadocus' letter 'a' appears 1 times.
# 'meriadocus' letter 'a' appears 1 times.
# 'meriasek' letter 'a' appears 2 times.
# 'bewnans' letter 'a' appears 1 times.
# 'chariotry' letter 'a' appears 1 times.
# 'hastati' letter 'a' appears 1 times.
# 'triarii' letter 'a' appears 1 times.
# 'cyberwar' letter 'a' appears 1 times.
# 'blackpowder' letter 'a' appears 1 times.
# 'flammables' letter 'a' appears 1 times.
# 'hegerland' letter 'a' appears 1 times.
# 'ommadawn' letter 'a' appears 2 times.
# 'aselin' letter 'a' appears 1 times.
# 'lunas' letter 'a' appears 6 times.
# 'airborn' letter 'a' appears 1 times.
# 'sallyangie' letter 'a' appears 2 times.
# 'whatevershebringswesing' letter 'a' appears 1 times.
# 'nathasha' letter 'a' appears 1 times.
# 'amadian' letter 'a' appears 1 times.
# 'redingensians' letter 'a' appears 1 times.
# 'forename' letter 'a' appears 1 times.
# 'barbaz' letter 'a' appears 1 times.
# 'foobaz' letter 'a' appears 1 times.
# 'gazonk' letter 'a' appears 3 times.
# 'quovadx' letter 'a' appears 1 times.
# 'hukarz' letter 'a' appears 2 times.
# 'ramsden' letter 'a' appears 2 times.
# 'blarg' letter 'a' appears 1 times.
# 'glarb' letter 'a' appears 1 times.
# 'kalaa' letter 'a' appears 1 times.
# 'initializer' letter 'a' appears 1 times.
# 'frack' letter 'a' appears 1 times.
# 'cheatem' letter 'a' appears 1 times.
# 'anytown' letter 'a' appears 2 times.
# 'ballybackanowhere' letter 'a' appears 1 times.
# 'ballygobackwards' letter 'a' appears 1 times.
# 'wassamatta' letter 'a' appears 1 times.
# 'lenna' letter 'a' appears 1 times.
# 'fulan' letter 'a' appears 2 times.
# 'matha' letter 'a' appears 1 times.
# 'kakvo' letter 'a' appears 1 times.
# 'flaf' letter 'a' appears 1 times.
# 'giraf' letter 'a' appears 1 times.
# 'duvelacky' letter 'a' appears 1 times.
# 'kalatehas' letter 'a' appears 1 times.
# 'hahaa' letter 'a' appears 1 times.
# 'machin' letter 'a' appears 1 times.
# 'normalverbraucher' letter 'a' appears 1 times.
# 'mustermann' letter 'a' appears 1 times.
# 'malakia' letter 'a' appears 1 times.
# 'almoni' letter 'a' appears 1 times.
# 'phalaan' letter 'a' appears 2 times.
# 'jakab' letter 'a' appears 1 times.
# 'fasz' letter 'a' appears 1 times.
# 'paperino' letter 'a' appears 1 times.
# 'bernasconi' letter 'a' appears 1 times.
# 'naninani' letter 'a' appears 1 times.
# 'appappan' letter 'a' appears 1 times.
# 'mayav' letter 'a' appears 1 times.
# 'patati' letter 'a' appears 1 times.
# 'patata' letter 'a' appears 1 times.
# 'fulano' letter 'a' appears 2 times.
# 'sicrano' letter 'a' appears 1 times.
# 'beltrano' letter 'a' appears 1 times.
# 'vasya' letter 'a' appears 1 times.
# 'mengano' letter 'a' appears 1 times.
# 'zutano' letter 'a' appears 2 times.
# 'sultano' letter 'a' appears 1 times.
# 'vaina' letter 'a' appears 1 times.
# 'pirola' letter 'a' appears 2 times.
# 'pirolita' letter 'a' appears 1 times.
# 'blahuj' letter 'a' appears 1 times.
# 'ugga' letter 'a' appears 1 times.
# 'kuppuswamy' letter 'a' appears 1 times.
# 'kadigan' letter 'a' appears 1 times.
# 'mondagreen' letter 'a' appears 1 times.
# 'amurray' letter 'a' appears 1 times.
# 'haffely' letter 'a' appears 1 times.
# 'gaffely' letter 'a' appears 2 times.
# 'gonward' letter 'a' appears 1 times.
# 'rizzatto' letter 'a' appears 1 times.
# 'kodaly' letter 'a' appears 1 times.
# ...
# 'gabions' letter 'a' appears 2 times.
# 'bagged' letter 'a' appears 1 times.
# 'mortarboard' letter 'a' appears 1 times.
# 'allwine' letter 'a' appears 4 times.
# 'gallopin' letter 'a' appears 5 times.
# 'barmaid' letter 'a' appears 1 times.
# 'horsecollar' letter 'a' appears 5 times.
# 'spanks' letter 'a' appears 1 times.
# 'panicks' letter 'a' appears 1 times.
# 'apprentence' letter 'a' appears 2 times.
# 'mousecapade' letter 'a' appears 1 times.
# 'amateurish' letter 'a' appears 1 times.
# 'mikkisofta' letter 'a' appears 1 times.
# 'krassner' letter 'a' appears 1 times.
# 'meherabad' letter 'a' appears 10 times.
# 'mandali' letter 'a' appears 7 times.
# 'merwan' letter 'a' appears 4 times.
# 'sheriar' letter 'a' appears 4 times.
# 'babajan' letter 'a' appears 3 times.
# 'tajuddin' letter 'a' appears 1 times.
# 'kedgaon' letter 'a' appears 1 times.
# 'upasni' letter 'a' appears 3 times.
# 'sakori' letter 'a' appears 2 times.
# 'sadguru' letter 'a' appears 1 times.
# 'manzil' letter 'a' appears 2 times.
# 'jessawalla' letter 'a' appears 1 times.
# 'avataric' letter 'a' appears 1 times.
# 'ashrams' letter 'a' appears 1 times.
# 'wayfarers' letter 'a' appears 1 times.
# 'aimlessness' letter 'a' appears 1 times.
# 'meherastana' letter 'a' appears 1 times.
# 'avatarhood' letter 'a' appears 1 times.
# 'sahavas' letter 'a' appears 1 times.
# 'amartithi' letter 'a' appears 3 times.
# 'sanskaras' letter 'a' appears 14 times.
# 'sanskara' letter 'a' appears 1 times.
# 'bhau' letter 'a' appears 2 times.
# 'kalchuri' letter 'a' appears 2 times.
# 'parvardigar' letter 'a' appears 1 times.
# 'avatarmeherbaba' letter 'a' appears 1 times.
# 'meherbaba' letter 'a' appears 2 times.
# 'meherbabatheavatar' letter 'a' appears 1 times.
# 'meherwan' letter 'a' appears 1 times.
# 'upasani' letter 'a' appears 1 times.
# 'shreeswami' letter 'a' appears 1 times.
# 'htmstates' letter 'a' appears 1 times.
# 'dastur' letter 'a' appears 1 times.
# 'meherazad' letter 'a' appears 1 times.
# 'superheat' letter 'a' appears 1 times.
# 'hollmann' letter 'a' appears 1 times.
# 'hollman' letter 'a' appears 1 times.
# 'innaccuracy' letter 'a' appears 1 times.
# 'radiowaves' letter 'a' appears 1 times.
# 'camb' letter 'a' appears 1 times.
# 'harlaxton' letter 'a' appears 2 times.
# 'allodially' letter 'a' appears 1 times.
# 'precaria' letter 'a' appears 1 times.
# 'aprisio' letter 'a' appears 4 times.
# 'manorialisation' letter 'a' appears 1 times.
# 'ruralisation' letter 'a' appears 1 times.
# 'lostlaysen' letter 'a' appears 1 times.
# 'laysen' letter 'a' appears 3 times.
# 'hemimetabolism' letter 'a' appears 2 times.
# 'naiads' letter 'a' appears 1 times.
# 'stagomantis' letter 'a' appears 1 times.
# 'mayfly' letter 'a' appears 2 times.
# 'hemimetabolic' letter 'a' appears 2 times.
# 'holometabolic' letter 'a' appears 1 times.
# 'aleyrodidae' letter 'a' appears 1 times.
# 'coccoidea' letter 'a' appears 1 times.
# 'allata' letter 'a' appears 1 times.
# 'ametabolism' letter 'a' appears 1 times.
# 'deaminates' letter 'a' appears 2 times.
# 'deaminated' letter 'a' appears 1 times.
# 'aurorix' letter 'a' appears 2 times.
# 'hyperserotonemia' letter 'a' appears 1 times.
# 'arrythmia' letter 'a' appears 1 times.
# 'rimas' letter 'a' appears 1 times.
# 'levodopa' letter 'a' appears 2 times.
# 'isocarboxazid' letter 'a' appears 1 times.
# 'marplan' letter 'a' appears 1 times.
# 'moclodura' letter 'a' appears 1 times.
# 'tranylcypromine' letter 'a' appears 1 times.
# 'parnate' letter 'a' appears 1 times.
# 'matey' letter 'a' appears 1 times.
# 'descedants' letter 'a' appears 1 times.
# 'swamphole' letter 'a' appears 1 times.
# 'phytopathology' letter 'a' appears 1 times.
# 'bary' letter 'a' appears 1 times.
# 'cosmopolitian' letter 'a' appears 1 times.
# 'fusarium' letter 'a' appears 1 times.
# 'aleukia' letter 'a' appears 1 times.
# 'shroomtalk' letter 'a' appears 1 times.
# 'hydriotaphia' letter 'a' appears 1 times.
# 'melencolia' letter 'a' appears 1 times.
# 'pudica' letter 'a' appears 1 times.
# 'invasivion' letter 'a' appears 1 times.
# 'albizia' letter 'a' appears 1 times.
# 'mimosas' letter 'a' appears 1 times.
# 'barneby' letter 'a' appears 1 times.
# 'sensitivae' letter 'a' appears 1 times.
# 'censitae' letter 'a' appears 1 times.
# 'mimosaceae' letter 'a' appears 1 times.
# 'thelate' letter 'a' appears 1 times.
# 'maraschino' letter 'a' appears 3 times.
# 'manhattans' letter 'a' appears 2 times.
# 'bav' letter 'a' appears 1 times.
# 'holwarda' letter 'a' appears 1 times.
# 'historiola' letter 'a' appears 1 times.
# 'mirae' letter 'a' appears 1 times.
# 'stellae' letter 'a' appears 1 times.
# 'bouillaud' letter 'a' appears 1 times.
# 'reflagged' letter 'a' appears 2 times.
# 'kaoampanttv' letter 'a' appears 1 times.
# 'vegesach' letter 'a' appears 1 times.
# 'monpa' letter 'a' appears 1 times.
# 'bodeguita' letter 'a' appears 2 times.
# 'draquecito' letter 'a' appears 1 times.
# 'paradisus' letter 'a' appears 2 times.
# 'fauxjito' letter 'a' appears 1 times.
# 'oryzae' letter 'a' appears 2 times.
# 'genmai' letter 'a' appears 1 times.
# 'inaka' letter 'a' appears 1 times.
# 'farmstyle' letter 'a' appears 1 times.
# 'taima' letter 'a' appears 1 times.
# 'sobamugi' letter 'a' appears 1 times.
# 'hadakamugi' letter 'a' appears 1 times.
# 'akizuki' letter 'a' appears 1 times.
# 'dengaku' letter 'a' appears 1 times.
# 'yakimochi' letter 'a' appears 1 times.
# 'nukamiso' letter 'a' appears 1 times.
# 'domnaill' letter 'a' appears 1 times.
# 'anlaf' letter 'a' appears 1 times.
# 'maormor' letter 'a' appears 1 times.
# 'auldearn' letter 'a' appears 1 times.
# 'donnchada' letter 'a' appears 1 times.
# 'malcolmus' letter 'a' appears 1 times.
# 'donnchad' letter 'a' appears 1 times.
# 'margaretsons' letter 'a' appears 1 times.
# 'etbard' letter 'a' appears 1 times.
# 'etgair' letter 'a' appears 1 times.
# 'alaxandair' letter 'a' appears 1 times.
# 'orkneyinga' letter 'a' appears 1 times.
# 'marcs' letter 'a' appears 1 times.
# 'tcpmsstarget' letter 'a' appears 1 times.
# 'andesitic' letter 'a' appears 1 times.
# 'hydrothermally' letter 'a' appears 1 times.
# 'trailhead' letter 'a' appears 1 times.
# 'shuksan' letter 'a' appears 1 times.
# 'kulshan' letter 'a' appears 1 times.
# 'stratovolcanoes' letter 'a' appears 1 times.
# 'amidships' letter 'a' appears 2 times.
# 'staalskibsvaerft' letter 'a' appears 1 times.
# 'mogas' letter 'a' appears 2 times.
# 'wartsilia' letter 'a' appears 1 times.
# 'dewayne' letter 'a' appears 1 times.
# 'geetha' letter 'a' appears 1 times.
# 'scumware' letter 'a' appears 1 times.
# 'stealware' letter 'a' appears 1 times.
# 'eulas' letter 'a' appears 1 times.
# 'spammer' letter 'a' appears 2 times.
# 'antisource' letter 'a' appears 1 times.
# 'castlecops' letter 'a' appears 1 times.
# 'casescontact' letter 'a' appears 1 times.
# 'cytrap' letter 'a' appears 1 times.
# 'hijackthis' letter 'a' appears 1 times.
# 'mcingvale' letter 'a' appears 1 times.
# 'lousisiana' letter 'a' appears 1 times.
# 'saqlain' letter 'a' appears 1 times.
# 'mathimalar' letter 'a' appears 1 times.
# 'ramamurthy' letter 'a' appears 1 times.
# 'hauls' letter 'a' appears 1 times.
# 'balled' letter 'a' appears 1 times.
# 'bishan' letter 'a' appears 1 times.
# 'murilatharan' letter 'a' appears 1 times.
# 'snaggletooth' letter 'a' appears 5 times.
# 'fanged' letter 'a' appears 1 times.
# 'petagno' letter 'a' appears 2 times.
# 'orgasmatron' letter 'a' appears 1 times.
# 'conservat' letter 'a' appears 1 times.
# 'dramatique' letter 'a' appears 1 times.
# 'fachbereich' letter 'a' appears 2 times.
# 'fachgebiet' letter 'a' appears 1 times.
# 'evangelischen' letter 'a' appears 1 times.
# 'oberlausitz' letter 'a' appears 1 times.
# 'conservatoires' letter 'a' appears 1 times.
# 'konservatorium' letter 'a' appears 7 times.
# 'musikakademie' letter 'a' appears 1 times.
# 'fachakademie' letter 'a' appears 1 times.
# 'chigiana' letter 'a' appears 1 times.
# 'artez' letter 'a' appears 1 times.
# 'rotterdams' letter 'a' appears 1 times.
# 'mannes' letter 'a' appears 1 times.
# 'thermalized' letter 'a' appears 1 times.
# 'garriga' letter 'a' appears 1 times.
# 'inflatons' letter 'a' appears 1 times.
# 'unitemporal' letter 'a' appears 2 times.
# 'hermeneutically' letter 'a' appears 1 times.
# 'campsie' letter 'a' appears 1 times.
# 'freewater' letter 'a' appears 1 times.
# 'hazza' letter 'a' appears 1 times.
# 'ratqa' letter 'a' appears 1 times.
# 'sameta' letter 'a' appears 2 times.
# 'degania' letter 'a' appears 1 times.
# 'tampon' letter 'a' appears 3 times.
# 'tampons' letter 'a' appears 1 times.
# 'matzo' letter 'a' appears 6 times.
# 'matza' letter 'a' appears 1 times.
# 'kilayim' letter 'a' appears 1 times.
# 'shmura' letter 'a' appears 1 times.
# 'farfel' letter 'a' appears 1 times.
# 'hosanna' letter 'a' appears 2 times.
# 'langeais' letter 'a' appears 2 times.
# 'marilou' letter 'a' appears 1 times.
# 'charmants' letter 'a' appears 1 times.
# 'shelagh' letter 'a' appears 1 times.
# 'accalaim' letter 'a' appears 1 times.
# 'cahier' letter 'a' appears 3 times.
# 'usmiani' letter 'a' appears 1 times.
# 'lansman' letter 'a' appears 1 times.
# 'mythopoeia' letter 'a' appears 1 times.
# 'silesiae' letter 'a' appears 1 times.
# 'terrarum' letter 'a' appears 1 times.
# 'cygman' letter 'a' appears 1 times.
# 'seach' letter 'a' appears 1 times.
# 'compartmentation' letter 'a' appears 1 times.
# 'prenylation' letter 'a' appears 1 times.
# 'metacyc' letter 'a' appears 1 times.
# 'nonredundant' letter 'a' appears 1 times.
# 'transductions' letter 'a' appears 1 times.
# 'pathcase' letter 'a' appears 1 times.
# 'postulata' letter 'a' appears 2 times.
# 'malthusians' letter 'a' appears 3 times.
# 'hyperexponential' letter 'a' appears 2 times.
# 'underpopulation' letter 'a' appears 1 times.
# 'donella' letter 'a' appears 1 times.
# 'soshyant' letter 'a' appears 1 times.
# 'millennialist' letter 'a' appears 2 times.
# 'pretribulationistic' letter 'a' appears 1 times.
# 'coracion' letter 'a' appears 1 times.
# 'chiliast' letter 'a' appears 1 times.
# 'tausendj' letter 'a' appears 4 times.
# 'unabsehbare' letter 'a' appears 1 times.
# 'distopian' letter 'a' appears 1 times.
# 'caneghem' letter 'a' appears 1 times.
# 'nival' letter 'a' appears 1 times.
# 'arkane' letter 'a' appears 1 times.
# 'futuresplash' letter 'a' appears 3 times.
# 'editability' letter 'a' appears 1 times.
# 'sharedobjects' letter 'a' appears 1 times.
# 'obfuscators' letter 'a' appears 2 times.
# 'xara' letter 'a' appears 1 times.
# 'presidia' letter 'a' appears 1 times.
# 'pointecast' letter 'a' appears 1 times.
# 'pointcast' letter 'a' appears 1 times.
# 'presentationpro' letter 'a' appears 1 times.
# 'flashblock' letter 'a' appears 1 times.
# 'johnhaller' letter 'a' appears 1 times.
# 'adblock' letter 'a' appears 1 times.
# 'futurepecoraro' letter 'a' appears 1 times.
# 'smartclips' letter 'a' appears 1 times.
# 'openlaszlo' letter 'a' appears 1 times.
# 'osflash' letter 'a' appears 1 times.
# 'alstad' letter 'a' appears 2 times.
# 'pentothal' letter 'a' appears 1 times.
# 'vicary' letter 'a' appears 1 times.
# 'caildini' letter 'a' appears 1 times.
# 'stahelski' letter 'a' appears 3 times.
# 'depluralization' letter 'a' appears 1 times.
# 'deindividuation' letter 'a' appears 2 times.
# 'langone' letter 'a' appears 4 times.
# 'galanter' letter 'a' appears 1 times.
# 'amitrani' letter 'a' appears 1 times.
# 'evangelizations' letter 'a' appears 3 times.
# 'unshattered' letter 'a' appears 1 times.
# 'revictimization' letter 'a' appears 2 times.
# 'passantinos' letter 'a' appears 1 times.
# 'kokkinakis' letter 'a' appears 3 times.
# 'clawar' letter 'a' appears 2 times.
# 'permamently' letter 'a' appears 1 times.
# 'stealhy' letter 'a' appears 1 times.
# 'playsatation' letter 'a' appears 1 times.
# 'arbeitsgruppe' letter 'a' appears 1 times.
# 'landeszentrale' letter 'a' appears 1 times.
# 'mottaghy' letter 'a' appears 1 times.
# 'gangitano' letter 'a' appears 1 times.
# 'archiveincludes' letter 'a' appears 1 times.
# 'matrixes' letter 'a' appears 1 times.
# 'dicionary' letter 'a' appears 1 times.
# 'manchurican' letter 'a' appears 1 times.
# 'procrastinated' letter 'a' appears 1 times.
# 'warmongers' letter 'a' appears 1 times.
# 'narev' letter 'a' appears 1 times.
# 'herwarth' letter 'a' appears 1 times.
# 'propanganda' letter 'a' appears 1 times.
# 'chicagowski' letter 'a' appears 1 times.
# 'hertza' letter 'a' appears 1 times.
# 'nonagression' letter 'a' appears 1 times.
# 'pollakov' letter 'a' appears 1 times.
# 'hounam' letter 'a' appears 4 times.
# 'avigdor' letter 'a' appears 1 times.
# 'contravene' letter 'a' appears 1 times.
# 'kayw' letter 'a' appears 1 times.
# 'taakov' letter 'a' appears 1 times.
# 'arieh' letter 'a' appears 1 times.
# 'mauvile' letter 'a' appears 1 times.
# 'maubila' letter 'a' appears 1 times.
# 'africatown' letter 'a' appears 1 times.
# 'blockaders' letter 'a' appears 1 times.
# 'farraguts' letter 'a' appears 1 times.
# 'baybears' letter 'a' appears 6 times.
# 'ichihara' letter 'a' appears 2 times.
# 'eyewall' letter 'a' appears 1 times.
# 'creola' letter 'a' appears 1 times.
# 'tranist' letter 'a' appears 1 times.
# 'archdiocesean' letter 'a' appears 1 times.
# 'vandebilt' letter 'a' appears 1 times.
# 'chamionship' letter 'a' appears 1 times.
# 'mobilians' letter 'a' appears 1 times.
# 'beaz' letter 'a' appears 1 times.
# 'caffey' letter 'a' appears 1 times.
# 'gorgas' letter 'a' appears 1 times.
# 'jamarcus' letter 'a' appears 1 times.
# 'siegelman' letter 'a' appears 1 times.
# 'saraland' letter 'a' appears 1 times.
# 'cassovia' letter 'a' appears 1 times.
# 'constanta' letter 'a' appears 1 times.
# 'pyongtaek' letter 'a' appears 1 times.
# 'gianjin' letter 'a' appears 1 times.
# 'oxidases' letter 'a' appears 2 times.
# 'monoamines' letter 'a' appears 3 times.
# 'astroglia' letter 'a' appears 1 times.
# 'catalized' letter 'a' appears 1 times.
# 'maos' letter 'a' appears 3 times.
# 'monoaminergic' letter 'a' appears 1 times.
# 'maltreated' letter 'a' appears 2 times.
# 'caspi' letter 'a' appears 2 times.
# 'yacco' letter 'a' appears 1 times.
# 'denishawn' letter 'a' appears 5 times.
# 'tamiris' letter 'a' appears 5 times.
# 'wigman' letter 'a' appears 6 times.
# 'ausdruckstanz' letter 'a' appears 3 times.
# 'tanztheater' letter 'a' appears 1 times.
# 'nagrin' letter 'a' appears 1 times.
# 'celichowska' letter 'a' appears 1 times.
# 'kriegsman' letter 'a' appears 1 times.
# 'libertatum' letter 'a' appears 1 times.
# 'distraint' letter 'a' appears 1 times.
# 'confirmatio' letter 'a' appears 1 times.
# 'cartarum' letter 'a' appears 1 times.
# 'libertates' letter 'a' appears 1 times.
# 'quasdam' letter 'a' appears 1 times.
# 'scriptas' letter 'a' appears 1 times.
# 'libertatibus' letter 'a' appears 1 times.
# 'magnacharta' letter 'a' appears 1 times.
# 'historicaldocuments' letter 'a' appears 1 times.
# 'mondian' letter 'a' appears 1 times.
# 'occaisionally' letter 'a' appears 1 times.
# 'relativistc' letter 'a' appears 1 times.
# 'mwatkins' letter 'a' appears 1 times.
# 'ehrhart' letter 'a' appears 3 times.
# 'polamidon' letter 'a' appears 1 times.
# 'roxane' letter 'a' appears 1 times.
# 'dispersable' letter 'a' appears 1 times.
# 'methadose' letter 'a' appears 1 times.
# 'alphacetylmethadol' letter 'a' appears 1 times.
# 'laam' letter 'a' appears 4 times.
# 'orlaam' letter 'a' appears 1 times.
# 'gustavson' letter 'a' appears 1 times.
# 'atlaslog' letter 'a' appears 1 times.
# 'jpegsales' letter 'a' appears 1 times.
# 'reinman' letter 'a' appears 1 times.
# 'leialohain' letter 'a' appears 1 times.
# 'killraven' letter 'a' appears 1 times.
# 'institutionalizing' letter 'a' appears 1 times.
# 'marvlogo' letter 'a' appears 1 times.
# 'fago' letter 'a' appears 1 times.
# 'salicrup' letter 'a' appears 1 times.
# 'doormat' letter 'a' appears 1 times.
# 'admax' letter 'a' appears 1 times.
# 'scharnberg' letter 'a' appears 1 times.
# 'cracy' letter 'a' appears 1 times.
# 'inegalitarian' letter 'a' appears 1 times.
# 'darwinisim' letter 'a' appears 1 times.
# 'intitially' letter 'a' appears 1 times.
# 'gennadi' letter 'a' appears 1 times.
# 'gorbachyova' letter 'a' appears 1 times.
# 'democratised' letter 'a' appears 1 times.
# 'clandenstine' letter 'a' appears 1 times.
# 'kajn' letter 'a' appears 1 times.
# 'zangief' letter 'a' appears 2 times.
# 'naevus' letter 'a' appears 3 times.
# 'flammeus' letter 'a' appears 3 times.
# 'gorbacheva' letter 'a' appears 1 times.
# 'mikhailgorbachev' letter 'a' appears 1 times.
# 'englander' letter 'a' appears 1 times.
# 'workmans' letter 'a' appears 1 times.
# 'metzada' letter 'a' appears 1 times.
# 'metzuda' letter 'a' appears 1 times.
# 'exortation' letter 'a' appears 1 times.

# %% [markdown]
# # Data Frame Task

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("IrisData").getOrCreate()
data = spark.read.json("/content/drive/MyDrive/Assigmnet/iris.json")

# %%
from pyspark.sql.functions import corr
data.select(corr("petalLength", "petalWidth")).show()
# Out:
# +-----------------------------+
# |corr(petalLength, petalWidth)|
# +-----------------------------+
# |            0.962865431402796|
# +-----------------------------+

# %%
data.filter(data.petalLength >= 1.4).select("sepalLength", "sepalWidth", "species").show()
# Out:
# +-----------+----------+-------+
# |sepalLength|sepalWidth|species|
# +-----------+----------+-------+
# |        5.1|       3.5| setosa|
# |        4.9|       3.0| setosa|
# |        4.6|       3.1| setosa|
# |        5.0|       3.6| setosa|
# |        5.4|       3.9| setosa|
# |        4.6|       3.4| setosa|
# |        5.0|       3.4| setosa|
# |        4.4|       2.9| setosa|
# |        4.9|       3.1| setosa|
# |        5.4|       3.7| setosa|
# |        4.8|       3.4| setosa|
# |        4.8|       3.0| setosa|
# |        5.7|       4.4| setosa|
# |        5.1|       3.5| setosa|
# |        5.7|       3.8| setosa|
# |        5.1|       3.8| setosa|
# |        5.4|       3.4| setosa|
# |        5.1|       3.7| setosa|
# |        5.1|       3.3| setosa|
# |        4.8|       3.4| setosa|
# +-----------+----------+-------+
# only showing top 20 rows
